# %% [markdown]
# # 3DSR - run script

# %%
scripted_titles = [
    ['CSVs/Scripted/D415_Close_Light.csv'], 
    ['CSVs/Scripted/D415_Far_Dark.csv'], 
    ['CSVs/Scripted/D415_Far_Light.csv'], 
    ['CSVs/Scripted/L515_Close_Light.csv'], 
    ['CSVs/Scripted/L515_Close_Light_Side.csv'], 
    ['CSVs/Scripted/L515_Far_Dark.csv'], 
    ['CSVs/Scripted/L515_Far_Dark_Side.csv'], 
    ['CSVs/Scripted/L515_Far_Light.csv']
    ]
    
sampled_titles = [
    ['CSVs/Sampled/0_876_Final.csv'],
    ['CSVs/Sampled/0_476_Final.csv'], 
    ['CSVs/Sampled/0_540_Final.csv'], 
    ['CSVs/Sampled/0_477_Final.csv'], 
    ['CSVs/Sampled/0_598_Final.csv']
    ]
    
titles = sampled_titles + scripted_titles
print(titles)
# Out:
# [['CSVs/Sampled/0_876_Final.csv'], ['CSVs/Sampled/0_476_Final.csv'], ['CSVs/Sampled/0_540_Final.csv'], ['CSVs/Sampled/0_477_Final.csv'], ['CSVs/Sampled/0_598_Final.csv'], ['CSVs/Scripted/D415_Close_Light.csv'], ['CSVs/Scripted/D415_Far_Dark.csv'], ['CSVs/Scripted/D415_Far_Light.csv'], ['CSVs/Scripted/L515_Close_Light.csv'], ['CSVs/Scripted/L515_Close_Light_Side.csv'], ['CSVs/Scripted/L515_Far_Dark.csv'], ['CSVs/Scripted/L515_Far_Dark_Side.csv'], ['CSVs/Scripted/L515_Far_Light.csv']]

# %% [markdown]
# ## Preprocess before R processing

# %%
from socialresearchcv.analysis.Preprocessor import preprocess_files

preprocess_files(titles)
# Out:
# CSVs/Sampled/0_876_Final.csv parsed successfully and saved to: Inputs/clean_0_876_Final.csv
# CSVs/Sampled/0_476_Final.csv parsed successfully and saved to: Inputs/clean_0_476_Final.csv
# CSVs/Sampled/0_540_Final.csv parsed successfully and saved to: Inputs/clean_0_540_Final.csv
# CSVs/Sampled/0_477_Final.csv parsed successfully and saved to: Inputs/clean_0_477_Final.csv
# CSVs/Sampled/0_598_Final.csv parsed successfully and saved to: Inputs/clean_0_598_Final.csv
# CSVs/Scripted/D415_Close_Light.csv parsed successfully and saved to: Inputs/clean_D415_Close_Light.csv
# CSVs/Scripted/D415_Far_Dark.csv parsed successfully and saved to: Inputs/clean_D415_Far_Dark.csv
# CSVs/Scripted/D415_Far_Light.csv parsed successfully and saved to: Inputs/clean_D415_Far_Light.csv
# CSVs/Scripted/L515_Close_Light.csv parsed successfully and saved to: Inputs/clean_L515_Close_Light.csv
# CSVs/Scripted/L515_Close_Light_Side.csv parsed successfully and saved to: Inputs/clean_L515_Close_Light_Side.csv
# ...

# %% [markdown]
# ## Run R processing

# %%
import subprocess
import os
# !Rscript --vanilla rcode/'3DSR_data_prep.R' {os.getcwd()}/
# Out:
# /bin/bash: Rscript: command not found

# %%
import subprocess
import os
# !Rscript --vanilla rcode/'3DSR_analysis.R' {os.getcwd()}
# Out:
# /bin/bash: Rscript: command not found
